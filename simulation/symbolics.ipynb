# %%
import sympy as sy

# %%
x, y, z = sy.symbols("x y z")

# %%
func = (x * 10 + 5) ** 2

# %%
func.expand()
# Out:
# 100*x**2 + 100*x + 25

# %%
func2 = (x + 1) * x * 100 + 25
func2.expand()
# Out:
# 100*x**2 + 100*x + 25

# %%
func3 = (x * 10 + 5) * (y * 10 + 5)
func3.expand()
# Out:
# 100*x*y + 50*x + 50*y + 25
