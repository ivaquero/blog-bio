# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from scipy.cluster import hierarchy
import networkx as nx

# %%
from sqlite3 import connect

# %%
conn = connect('../../my-trifles/Extensions/db-bio-taxa.db')
taxa = pd.read_sql('select * from species', conn)
taxa.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/integzz/Documents/blog-stats/binfo.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/integzz/Documents/blog-stats/binfo.ipynb#ch0000003?line=0'>1</a> conn = connect('../../my-trifles/Extensions/db-bio-taxa.db')
#       <a href='vscode-notebook-cell:/Users/integzz/Documents/blog-stats/binfo.ipynb#ch0000003?line=1'>2</a> taxa = pd.read_sql('select * from species', conn)
#       <a href='vscode-notebook-cell:/Users/integzz/Documents/blog-stats/binfo.ipynb#ch0000003?line=2'>3</a> taxa.head()
#
# OperationalError: unable to open database file

# %%
meta = taxa.query("parent == 1 or parent == 131567")
meta
# Out:
#       taxid  parent                spname      common          rank  \
# 1     10239       1               Viruses              superkingdom
# 2    131567       1    cellular organisms                   no rank
# 3   2787823       1  unclassified entries                   no rank
# 4   2787854       1         other entries                   no rank
# 39        2  131567              Bacteria  eubacteria  superkingdom
# 40     2157  131567               Archaea              superkingdom
# 41     2759  131567             Eukaryota  eucaryotes  superkingdom
#
#             track
# 1         10239,1
# 2        131567,1
# 3       2787823,1
# 4       2787854,1
# 39     2,131567,1
# 40  2157,131567,1
# 41  2759,131567,1

# %%
cells = taxa[taxa.track.str.contains('131567')]
cells
# Out:
#           taxid   parent                         spname      common  \
# 2        131567        1             cellular organisms
# 39            2   131567                       Bacteria  eubacteria
# 40         2157   131567                        Archaea
# 41         2759   131567                      Eukaryota  eucaryotes
# 2369       1224        2                 Proteobacteria
# ...         ...      ...                            ...         ...
# 2345960  368082  2630923         Cyprinodon sp. US-2006
# 2345961  722606  2624860   Floridichthys sp. 1 MVM-2009
# 2345962  327764    95543  Tropheops tropheops gracilior
# 2345963  327765    95543  Tropheops tropheops tropheops
# 2345964  445559    95543    Tropheops tropheops romandi
#
#                  rank                                              track
# 2             no rank                                           131567,1
# 39       superkingdom                                         2,131567,1
# 40       superkingdom                                      2157,131567,1
# 41       superkingdom                                      2759,131567,1
# 2369           phylum                                    1224,2,131567,1
# ...               ...                                                ...
# 2345960       species  368082,2630923,28741,136838,136836,8076,8087,2...
# 2345961       species  722606,2624860,30741,136838,136836,8076,8087,2...
# 2345962    subspecies  327764,95543,1905357,702376,319058,318546,3190...
# 2345963    subspecies  327765,95543,1905357,702376,319058,318546,3190...
# 2345964    subspecies  445559,95543,1905357,702376,319058,318546,3190...
#
# [2109174 rows x 6 columns]

# %% [markdown]
# ## Bacteria

# %%
bacteria = cells[cells.track.str.contains('2,131567,1')].sort_values('taxid')
bacteria
# Out:
#           taxid   parent                    spname      common          rank  \
# 39            2   131567                  Bacteria  eubacteria  superkingdom
# 128742        6   335928              Azorhizobium                     genus
# 154680        7        6  Azorhizobium caulinodans                   species
# 148105        9    32199       Buchnera aphidicola                   species
# 128072       10  1706371                Cellvibrio                     genus
# ...         ...      ...                       ...         ...           ...
# 485083  2860197   185979     Bacillus sp. MCCB 382                   species
# 128043  2860205      712                  Canicola                     genus
# 129792  2860235  2820280          Glacieibacterium                     genus
# 163495  2860291   213422        Geomesophilobacter                     genus
# 357861  2860296  2651583     unclassified Geomonas                   no rank
#
#                                                     track
# 39                                             2,131567,1
# 128742                 6,335928,356,28211,1224,2,131567,1
# 154680               7,6,335928,356,28211,1224,2,131567,1
# 148105         9,32199,1903409,91347,1236,1224,2,131567,1
# 128072            10,1706371,1706369,1236,1224,2,131567,1
# ...                                                   ...
# 485083  2860197,185979,1386,186817,1385,91061,1239,178...
# 128043            2860205,712,135625,1236,1224,2,131567,1
# 129792       2860235,2820280,204457,28211,1224,2,131567,1
# 163495   2860291,213422,69541,28221,68525,1224,2,131567,1
# 357861  2860296,2651583,213422,69541,28221,68525,1224,...
#
# [523895 rows x 6 columns]

# %%
rank_sort = bacteria[['taxid',
                      'rank']].groupby('rank').agg('count').sort_values(
                          by='taxid', ascending=False)
rank_sort
# Out:
#                    taxid
# rank
# species           465740
# strain             40936
# no rank             9247
# genus               4463
# family               637
# subspecies           633
# forma specialis      522
# isolate              503
# order                253
# serotype             246
# phylum               167
# serogroup            137
# clade                129
# class                110
# species group         86
# species subgroup      26
# varietas              26
# suborder               7
# biotype                7
# pathogroup             5
# subclass               5
# forma                  4
# tribe                  2
# subfamily              1
# subgenus               1
# subphylum              1
# superkingdom           1

# %%
len(rank_sort)
# Out:
# 27

# %%
df = pd.DataFrame(columns=rank_sort.index.values)
df.head()
# Out:
# Empty DataFrame
# Columns: [species, strain, no rank, genus, family, subspecies, forma specialis, isolate, order, serotype, phylum, serogroup, clade, class, species group, species subgroup, varietas, suborder, biotype, pathogroup, subclass, forma, tribe, subfamily, subgenus, subphylum, superkingdom]
# Index: []
#
# [0 rows x 27 columns]

# %%
bacteria.query('parent == 1385').query('rank == "family"')
# Out:
#          taxid parent                  spname common    rank  \
# 136021   90964   1385       Staphylococcaceae         family
# 136022  186817   1385             Bacillaceae         family
# 136023  186818   1385          Planococcaceae         family
# 136024  186820   1385            Listeriaceae         family
# 136025  186821   1385   Sporolactobacillaceae         family
# 136026  186822   1385        Paenibacillaceae         family
# 136027  186823   1385     Alicyclobacillaceae         family
# 136028  186824   1385  Thermoactinomycetaceae         family
# 136029  538998   1385           Pasteuriaceae         family
#
#                                             track
# 136021   90964,1385,91061,1239,1783272,2,131567,1
# 136022  186817,1385,91061,1239,1783272,2,131567,1
# 136023  186818,1385,91061,1239,1783272,2,131567,1
# 136024  186820,1385,91061,1239,1783272,2,131567,1
# 136025  186821,1385,91061,1239,1783272,2,131567,1
# 136026  186822,1385,91061,1239,1783272,2,131567,1
# 136027  186823,1385,91061,1239,1783272,2,131567,1
# 136028  186824,1385,91061,1239,1783272,2,131567,1
# 136029  538998,1385,91061,1239,1783272,2,131567,1

# %%
bacteria.query('parent == 91347').query('rank == "family"')
# Out:
#          taxid parent               spname common    rank  \
# 96859      543  91347   Enterobacteriaceae         family
# 96863  1771359  91347       Thorselliaceae         family
# 96864  1903409  91347          Erwiniaceae         family
# 96865  1903410  91347    Pectobacteriaceae         family
# 96866  1903411  91347         Yersiniaceae         family
# 96867  1903412  91347           Hafniaceae         family
# 96868  1903414  91347       Morganellaceae         family
# 96869  1903416  91347         Budviciaceae         family
# 96870  2812006  91347  Bruguierivoracaceae         family
#
#                                     track
# 96859      543,91347,1236,1224,2,131567,1
# 96863  1771359,91347,1236,1224,2,131567,1
# 96864  1903409,91347,1236,1224,2,131567,1
# 96865  1903410,91347,1236,1224,2,131567,1
# 96866  1903411,91347,1236,1224,2,131567,1
# 96867  1903412,91347,1236,1224,2,131567,1
# 96868  1903414,91347,1236,1224,2,131567,1
# 96869  1903416,91347,1236,1224,2,131567,1
# 96870  2812006,91347,1236,1224,2,131567,1

# %%
bacteria.query('parent == 72274').query('rank == "family"')
# Out:
#          taxid parent             spname common    rank  \
# 96853      468  72274      Moraxellaceae         family
# 96856   135621  72274   Pseudomonadaceae         family
# 96858  1827282  72274  Ventosimonadaceae         family
#
#                                     track
# 96853      468,72274,1236,1224,2,131567,1
# 96856   135621,72274,1236,1224,2,131567,1
# 96858  1827282,72274,1236,1224,2,131567,1

# %%
sp_list = [
    'Bacillus subtilis', 'Escherichia coli', 'Pseudomonas aeruginosa',
    'Staphylococcus epidermidis', 'Enterococcus faecalis'
]

for ind, sp in enumerate(sp_list):
    species = bacteria.query(f"spname == '{sp}'")

    tracks = species.track.str.split(',').values[0]

    for _id in tracks:
        taxon = bacteria.query(f"taxid == {_id}")
        df.loc[ind, taxon['rank'].values] = taxon['spname'].values

df_new = df.dropna(axis=1)
df_new
# Out:
#                       species           genus              family  \
# 0           Bacillus subtilis        Bacillus         Bacillaceae
# 1            Escherichia coli     Escherichia  Enterobacteriaceae
# 2      Pseudomonas aeruginosa     Pseudomonas    Pseudomonadaceae
# 3  Staphylococcus epidermidis  Staphylococcus   Staphylococcaceae
# 4       Enterococcus faecalis    Enterococcus     Enterococcaceae
#
#               order          phylum                class superkingdom
# 0        Bacillales      Firmicutes              Bacilli     Bacteria
# 1  Enterobacterales  Proteobacteria  Gammaproteobacteria     Bacteria
# 2   Pseudomonadales  Proteobacteria  Gammaproteobacteria     Bacteria
# 3        Bacillales      Firmicutes              Bacilli     Bacteria
# 4   Lactobacillales      Firmicutes              Bacilli     Bacteria

# %%
sp_list = [
    'Bacillus subtilis', 'Escherichia coli', 'Pseudomonas aeruginosa',
    'Staphylococcus epidermidis', 'Listeria monocytogenes',
    'Micrococcus luteus'
]

for ind, sp in enumerate(sp_list):
    species = bacteria.query(f"spname == '{sp}'")

    tracks = species.track.str.split(',').values[0]

    for _id in tracks:
        taxon = bacteria.query(f"taxid == {_id}")
        df.loc[ind, taxon['rank'].values] = taxon['taxid'].values

df_new_id = df.dropna(axis=1)
df_new_id = df_new_id.copy()
df_new_id['species'] = sp_list
df_new_id
# Out:
#                       species genus  family  order  phylum  class superkingdom
# 0           Bacillus subtilis  1386  186817   1385    1239  91061            2
# 1            Escherichia coli   561     543  91347    1224   1236            2
# 2      Pseudomonas aeruginosa   286  135621  72274    1224   1236            2
# 3  Staphylococcus epidermidis  1279   90964   1385    1239  91061            2
# 4      Listeria monocytogenes  1637  186820   1385    1239  91061            2
# 5          Micrococcus luteus  1269    1268  85006  201174   1760            2

# %%
df_new_id.columns[:-1]
# Out:
# Index(['species', 'genus', 'family', 'order', 'phylum', 'class'], dtype='object')

# %% [markdown]
# ## tree

# %%
sp_names = [
    '$Bacillus\ subtilis$', '$Escherichia\ coli$', '$Pseudomonas\ aeruginosa$',
    '$Staphylococcus\ epidermidis$', '$Listeria\ monocytogenes$',
    '$Micrococcus luteus$'
]

hierarchy.set_link_color_palette(['r', 'g'])

_, ax = plt.subplots(figsize=(12, 8), dpi=80)

z = hierarchy.linkage(df_new_id[df_new_id.columns[1:-1]],
                      method='single',
                      metric='jaccard')

dend = hierarchy.dendrogram(z,
                            labels=sp_names,
                            leaf_font_size='x-large',
                            orientation='left',
                            above_threshold_color='blue')

ax.set(xlabel="", xticklabels="")
# plt.savefig('2.2-distance.svg')

# %% [markdown]
# ## phylum

# %%
caulo = bacteria.query(f"spname == 'Caulobacterales'")
caulo
# Out:
#         taxid parent           spname common   rank  \
# 69749  204458  28211  Caulobacterales         order
#
#                               track
# 69749  204458,28211,1224,2,131567,1

# %%
child_caulo = bacteria[bacteria.track.str.contains(f"{caulo.taxid.values[0]}")]
child_caulo
# Out:
#           taxid   parent                                spname common  \
# 129794       20    76892                      Phenylobacterium
# 159096       21       20             Phenylobacterium immobile
# 129795       75    76892                           Caulobacter
# 334011       78  2648921                       Caulobacter sp.
# 159134      293    41275                Brevundimonas diminuta
# ...         ...      ...                                   ...    ...
# 105968  2822437  2044589  unclassified Candidatus Sabulitectum
# 136003  2822438  2822437           Candidatus Sabulitectum sp.
# 334571  2823693  2648921                    Caulobacter sp. S6
# 335907  2838843  2622653                Brevundimonas sp. TTT9
# 335972  2840468  2628350              Asticcacaulis sp. AND118
#
#            rank                                              track
# 129794    genus              20,76892,204458,28211,1224,2,131567,1
# 159096  species           21,20,76892,204458,28211,1224,2,131567,1
# 129795    genus              75,76892,204458,28211,1224,2,131567,1
# 334011  species   78,2648921,75,76892,204458,28211,1224,2,131567,1
# 159134  species       293,41275,76892,204458,28211,1224,2,131567,1
# ...         ...                                                ...
# 105968  no rank         2822437,2044589,1729712,1783270,2,131567,1
# 136003  species  2822438,2822437,2044589,1729712,1783270,2,1315...
# 334571  species  2823693,2648921,75,76892,204458,28211,1224,2,1...
# 335907  species  2838843,2622653,41275,76892,204458,28211,1224,...
# 335972  species  2840468,2628350,76890,76892,204458,28211,1224,...
#
# [2323 rows x 6 columns]

# %%
child_caulo.query("rank == 'genus'")
# Out:
#           taxid   parent                   spname common   rank  \
# 129794       20    76892         Phenylobacterium         genus
# 129795       75    76892              Caulobacter         genus
# 129796    41275    76892            Brevundimonas         genus
# 129797    76890    76892            Asticcacaulis         genus
# 129800   267929    76892            Nitrobacteria         genus
# 74499   2044589  1729712  Candidatus Sabulitectum         genus
# 129801  2052989    76892          Aquidulcibacter         genus
# 129802  2768684    76892              Terricaulis         genus
#
#                                              track
# 129794       20,76892,204458,28211,1224,2,131567,1
# 129795       75,76892,204458,28211,1224,2,131567,1
# 129796    41275,76892,204458,28211,1224,2,131567,1
# 129797    76890,76892,204458,28211,1224,2,131567,1
# 129800   267929,76892,204458,28211,1224,2,131567,1
# 74499           2044589,1729712,1783270,2,131567,1
# 129801  2052989,76892,204458,28211,1224,2,131567,1
# 129802  2768684,76892,204458,28211,1224,2,131567,1

# %% [markdown]
# # Networks
